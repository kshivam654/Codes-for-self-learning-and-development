setup.py'"'"'; __file__='"'"'/private/var/folders/qg/95cbyh_564vbrm_c42_67mfc0000gn/T/pip-install-d6ojk52o/psycopg2_16141584d8d24773bac1612b31b26ce9/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/qg/95cbyh_564vbrm_c42_67mfc0000gn/T/pip-pip-egg-info-2j9atk5n
#          cwd: /private/var/folders/qg/95cbyh_564vbrm_c42_67mfc0000gn/T/pip-install-d6ojk52o/psycopg2_16141584d8d24773bac1612b31b26ce9/
#     Complete output (6 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/private/var/folders/qg/95cbyh_564vbrm_c42_67mfc0000gn/T/pip-install-d6ojk52o/psycopg2_16141584d8d24773bac1612b31b26ce9/setup.py", line 238
#         except Warning, w:
#                       ^
#     SyntaxError: invalid syntax
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/e0/1c/f0843f50a69fba3db880e9b267d36f6709bbf31a36fc46b82f75e8975ede/psycopg2-2.0.14.tar.gz#sha256=902607cdbe1195a00694d2b477eed8429eda433caaa0eb6ff7f80883e1c17ac7 (from https://pypi.org/simple/psycopg2/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Using cached psycopg2-2.0.13.tar.gz (258 kB)
#     ERROR: Command errored out with exit status 1:
#      command: /Users/shivam/opt/anaconda3/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/qg/95cbyh_564vbrm_c42_67mfc0000gn/T/pip-install-d6ojk52o/psycopg2_797135ff21ee422f94907ab9f54270a0/setup.py'"'"'; __file__='"'"'/private/var/folders/qg/95cbyh_564vbrm_c42_67mfc0000gn/T/pip-install-d6ojk52o/psycopg2_797135ff21ee422f94907ab9f54270a0/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/qg/95cbyh_564vbrm_c42_67mfc0000gn/T/pip-pip-egg-info-xostcwzp
#          cwd: /private/var/folders/qg/95cbyh_564vbrm_c42_67mfc0000gn/T/pip-install-d6ojk52o/psycopg2_797135ff21ee422f94907ab9f54270a0/
#     Complete output (6 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/private/var/folders/qg/95cbyh_564vbrm_c42_67mfc0000gn/T/pip-install-d6ojk52o/psycopg2_797135ff21ee422f94907ab9f54270a0/setup.py", line 233
#         except Warning, w:
#                       ^
#     SyntaxError: invalid syntax
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/3a/7a/968afcb86b1958ae963a3aaa42c561e3ed2c2d4a8b773622b03856a16248/psycopg2-2.0.13.tar.gz#sha256=a15e622e101b16aa8ad44813d8fb1eced91379396c054aacbfa3ad658352332b (from https://pypi.org/simple/psycopg2/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Using cached psycopg2-2.0.12.tar.gz (256 kB)
#     ERROR: Command errored out with exit status 1:
#      command: /Users/shivam/opt/anaconda3/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/qg/95cbyh_564vbrm_c42_67mfc0000gn/T/pip-install-d6ojk52o/psycopg2_68d8a660e33b43c980fdeceaf1243e62/setup.py'"'"'; __file__='"'"'/private/var/folders/qg/95cbyh_564vbrm_c42_67mfc0000gn/T/pip-install-d6ojk52o/psycopg2_68d8a660e33b43c980fdeceaf1243e62/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/qg/95cbyh_564vbrm_c42_67mfc0000gn/T/pip-pip-egg-info-5e28_1nj
#          cwd: /private/var/folders/qg/95cbyh_564vbrm_c42_67mfc0000gn/T/pip-install-d6ojk52o/psycopg2_68d8a660e33b43c980fdeceaf1243e62/
#     Complete output (6 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/private/var/folders/qg/95cbyh_564vbrm_c42_67mfc0000gn/T/pip-install-d6ojk52o/psycopg2_68d8a660e33b43c980fdeceaf1243e62/setup.py", line 225
#         except Warning, w:
#                       ^
#     SyntaxError: invalid syntax
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/6a/8d/ee5c330823d527a5cd14c833063f825211d7b5de6e4897f72e250c107d85/psycopg2-2.0.12.tar.gz#sha256=542c187531e756867fb60034c393b6f2beca34eeeb3ce2e0089a2b6fb8be1292 (from https://pypi.org/simple/psycopg2/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Using cached psycopg2-2.0.11.tar.gz (255 kB)
#     ERROR: Command errored out with exit status 1:
#      command: /Users/shivam/opt/anaconda3/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/qg/95cbyh_564vbrm_c42_67mfc0000gn/T/pip-install-d6ojk52o/psycopg2_4281de8f1ddc4004bbf935ff60385682/setup.py'"'"'; __file__='"'"'/private/var/folders/qg/95cbyh_564vbrm_c42_67mfc0000gn/T/pip-install-d6ojk52o/psycopg2_4281de8f1ddc4004bbf935ff60385682/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/qg/95cbyh_564vbrm_c42_67mfc0000gn/T/pip-pip-egg-info-0_31z_lv
#          cwd: /private/var/folders/qg/95cbyh_564vbrm_c42_67mfc0000gn/T/pip-install-d6ojk52o/psycopg2_4281de8f1ddc4004bbf935ff60385682/
#     Complete output (6 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/private/var/folders/qg/95cbyh_564vbrm_c42_67mfc0000gn/T/pip-install-d6ojk52o/psycopg2_4281de8f1ddc4004bbf935ff60385682/setup.py", line 225
#         except Warning, w:
#                       ^
#     SyntaxError: invalid syntax
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/2d/d7/496da11d7c81971870ddd36800419c4f84e8f6208aac5eabedf9f7748729/psycopg2-2.0.11.tar.gz#sha256=e6b4e0e41df97441eff34e00065376414da6488e0d55848a45cd77551dbae434 (from https://pypi.org/simple/psycopg2/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Using cached psycopg2-2.0.10.tar.gz (255 kB)
#     ERROR: Command errored out with exit status 1:
#      command: /Users/shivam/opt/anaconda3/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/qg/95cbyh_564vbrm_c42_67mfc0000gn/T/pip-install-d6ojk52o/psycopg2_b9b19182aea140cfb88667ff0f048820/setup.py'"'"'; __file__='"'"'/private/var/folders/qg/95cbyh_564vbrm_c42_67mfc0000gn/T/pip-install-d6ojk52o/psycopg2_b9b19182aea140cfb88667ff0f048820/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/qg/95cbyh_564vbrm_c42_67mfc0000gn/T/pip-pip-egg-info-xhjcgloo
#          cwd: /private/var/folders/qg/95cbyh_564vbrm_c42_67mfc0000gn/T/pip-install-d6ojk52o/psycopg2_b9b19182aea140cfb88667ff0f048820/
#     Complete output (5 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/private/var/folders/qg/95cbyh_564vbrm_c42_67mfc0000gn/T/pip-install-d6ojk52o/psycopg2_b9b19182aea140cfb88667ff0f048820/setup.py", line 50, in <module>
#         import ConfigParser
#     ModuleNotFoundError: No module named 'ConfigParser'
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/19/79/35c7596bab4456f3610c12ec542a94d51c6781ced587d1d85127210b879b/psycopg2-2.0.10.tar.gz#sha256=e40cc04b43849085725076ae134bfef9e3b087f6dd7c964aeeb930e2f0bc14ab (from https://pypi.org/simple/psycopg2/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
# ERROR: Could not find a version that satisfies the requirement psycopg2 (from versions: 2.0.10, 2.0.11, 2.0.12, 2.0.13, 2.0.14, 2.2.0, 2.2.1, 2.2.2, 2.3.0, 2.3.1, 2.3.2, 2.4, 2.4.1, 2.4.2, 2.4.3, 2.4.4, 2.4.5, 2.4.6, 2.5, 2.5.1, 2.5.2, 2.5.3, 2.5.4, 2.5.5, 2.6, 2.6.1, 2.6.2, 2.7, 2.7.1, 2.7.2, 2.7.3, 2.7.3.1, 2.7.3.2, 2.7.4, 2.7.5, 2.7.6, 2.7.6.1, 2.7.7, 2.8, 2.8.1, 2.8.2, 2.8.3, 2.8.4, 2.8.5, 2.8.6, 2.9, 2.9.1, 2.9.2, 2.9.3)
# ERROR: No matching distribution found for psycopg2

# %%
import psycopg2
import pandas as pd
import numpy as np

#establishing the connection
conn = psycopg2.connect(
   database="postgres", user='postgres', password='password', host='127.0.0.1', port= '5432'
)
#Creating a cursor object using the cursor() method
cursor = conn.cursor()

#Executing an MYSQL function using the execute() method
cursor.execute("SELECT table_name FROM information_schema.tables WHERE table_type='BASE TABLE' AND table_schema='public';")

# Fetch a single row using fetchone() method.
datas = cursor.fetchall()

df = pd.DataFrame([], columns=['Table Name', 'Column Name', 'Data type'])

for data in datas:
    query = "SELECT * FROM information_schema.columns WHERE table_schema = 'your_schema' AND table_name   = '{}';".format(data)
    
    cursor.execute(query)
    t_details = cursor.fetchall()
    
    df = df.append([data, '', ''])
    for detail in t_details:
        df = df.append(['', detail[0], detail[1]], ignore_index=True)
        
        
df.to_csv("table_details.xlsx")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /var/folders/qg/95cbyh_564vbrm_c42_67mfc0000gn/T/ipykernel_72071/279853518.py in <module>
#       2
#       3 #establishing the connection
# ----> 4 conn = psycopg2.connect(
#       5    database="postgres", user='postgres', password='password', host='127.0.0.1', port= '5432'
#       6 )
#
# ~/opt/anaconda3/lib/python3.9/site-packages/psycopg2/__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     125
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#     129         conn.cursor_factory = cursor_factory
#
# OperationalError: could not connect to server: Connection refused
# 	Is the server running on host "127.0.0.1" and accepting
# 	TCP/IP connections on port 5432?

# %%
#Closing the connection
conn.close()
